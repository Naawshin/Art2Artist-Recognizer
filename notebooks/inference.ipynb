# %% [markdown]
# # **Setup**

# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Data Science/Art Recognizer
# Out:
# /content/drive/My Drive/Data Science/Art Recognizer

# %%
#import os
#os.mkdir('test_images')
version = 1
img_path = 'test_images'
model_path = f"models/art-recognizer-v2.pkl"

# %%
model = load_learner(model_path)
# Out:
# /usr/local/lib/python3.12/dist-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")

# %% [markdown]
# # **Inference 1**

# %% [markdown]
# **Target:** Vangogh

# %%
img = Image.open(f'{img_path}/vangogh t3.jpeg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/vangogh t3.jpeg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("Vincent van Gogh's artwork",
#  tensor(19),
#  tensor([4.6639e-04, 1.4416e-02, 3.6427e-02, 1.2837e-03, 1.8302e-04, 2.2542e-03,
#          8.4386e-03, 1.1220e-01, 4.3140e-04, 3.4315e-01, 2.2814e-03, 1.8937e-03,
#          2.1274e-03, 6.6914e-02, 1.0446e-03, 1.5235e-03, 4.0551e-04, 1.9368e-02,
#          6.0191e-03, 3.7918e-01]))

# %%
model.predict(f'{img_path}/unknown.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("Vincent van Gogh's artwork",
#  tensor(19),
#  tensor([1.2018e-04, 1.9235e-03, 2.2999e-02, 1.6559e-01, 3.0067e-03, 2.1491e-03,
#          8.9895e-02, 9.4317e-03, 5.2990e-02, 1.1154e-02, 2.3967e-03, 5.3634e-02,
#          9.1923e-03, 5.9249e-04, 8.2352e-04, 8.1526e-04, 2.2281e-03, 7.3851e-05,
#          2.5027e-04, 5.7073e-01]))

# %% [markdown]
# # **Inference 2**

# %% [markdown]
# Target: Frida Kahlo

# %%
img = Image.open(f'{img_path}/download (2).jpeg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=120x120>

# %%
model.predict(f'{img_path}/download (2).jpeg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("Henri Matisse's artwork",
#  tensor(7),
#  tensor([9.2867e-05, 2.0596e-03, 3.9228e-04, 7.3894e-04, 4.6854e-04, 1.0269e-01,
#          2.4651e-04, 8.7648e-01, 2.4579e-04, 2.3993e-05, 1.1666e-04, 2.2239e-04,
#          1.9261e-05, 1.3358e-04, 6.3823e-06, 1.6005e-02, 1.5535e-05, 3.4809e-05,
#          1.8079e-06, 6.2277e-07]))

# %%
img = Image.open(f'{img_path}/download.jpeg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/download.jpeg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("Henri Matisse's artwork",
#  tensor(7),
#  tensor([8.4908e-05, 1.4877e-04, 1.3259e-02, 1.9213e-03, 5.5717e-03, 1.5961e-03,
#          1.5143e-03, 5.9042e-01, 6.5088e-03, 2.1009e-03, 1.7886e-04, 1.0822e-02,
#          8.0245e-05, 2.6416e-01, 2.4497e-03, 9.1659e-04, 6.4413e-05, 2.7222e-04,
#          8.6562e-02, 1.1369e-02]))

# %%
img = Image.open(f'{img_path}/images (1).jpeg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=93x128>

# %%
model.predict(f'{img_path}/images (1).jpeg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("Caravaggio's artwork",
#  tensor(0),
#  tensor([3.7307e-01, 6.1826e-04, 3.7879e-03, 1.0904e-01, 1.4142e-03, 2.1708e-04,
#          1.8771e-03, 3.1975e-03, 6.7823e-03, 4.8754e-03, 1.3631e-02, 2.6807e-03,
#          3.0128e-02, 7.1756e-02, 1.2566e-03, 1.0457e-03, 2.4573e-01, 5.8956e-02,
#          3.3446e-02, 3.6484e-02]))
